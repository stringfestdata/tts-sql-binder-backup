# %%
import pandas as pd
import duckdb

deals = pd.read_csv("Deals/Deals.csv")

duckdb.sql("""
SELECT *
FROM deals
LIMIT 10
""").df()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 import duckdb
#       4 customers = pd.read_csv("customers.csv")
#       6 duckdb.sql("""
#       7 SELECT *
#       8 FROM customers
#       9 LIMIT 10
#      10 """).df()
#
# ModuleNotFoundError: No module named 'duckdb'
